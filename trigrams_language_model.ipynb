# %% [markdown]
# # Trigram Lyrics generation
#
# ## Sample sentence:
# Carlos needs a haircut
#
# ## Bigrams:
#
# - (Carlos, needs)
# - (needs, a)
# - (a, haircut)
#
# ## Trigrams
#
# - (Carlos, needs, a)
# - (needs, a, haircut)
#
# ## Acknowledgments
# Based on the Poetry-generator talk made by Carlos Castro - Software Engineer at Microsoft

# %% [markdown]
# # Setup

# %%
# Imports

import nltk
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict

# %%
# Download data

nltk.download('reuters')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package reuters to
# [nltk_data]     C:\Users\lirosale\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lirosale\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# # Exploration

# %%
# Inspect first sentence

first_sentence = reuters.sents()[0]
print(first_sentence) # [u'ASIAN', u'EXPORTERS', u'FEAR', u'DAMAGE', u'FROM' ...
# Out:
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', '.', 'S', '.-', 'JAPAN', 'RIFT', 'Mounting', 'trade', 'friction', 'between', 'the', 'U', '.', 'S', '.', 'And', 'Japan', 'has', 'raised', 'fears', 'among', 'many', 'of', 'Asia', "'", 's', 'exporting', 'nations', 'that', 'the', 'row', 'could', 'inflict', 'far', '-', 'reaching', 'economic', 'damage', ',', 'businessmen', 'and', 'officials', 'said', '.']

# %%
# Show trigrams for first sentence

print(list(trigrams(first_sentence, pad_left=True, pad_right=True)))
# Out:
# [(None, None, 'ASIAN'), (None, 'ASIAN', 'EXPORTERS'), ('ASIAN', 'EXPORTERS', 'FEAR'), ('EXPORTERS', 'FEAR', 'DAMAGE'), ('FEAR', 'DAMAGE', 'FROM'), ('DAMAGE', 'FROM', 'U'), ('FROM', 'U', '.'), ('U', '.', 'S'), ('.', 'S', '.-'), ('S', '.-', 'JAPAN'), ('.-', 'JAPAN', 'RIFT'), ('JAPAN', 'RIFT', 'Mounting'), ('RIFT', 'Mounting', 'trade'), ('Mounting', 'trade', 'friction'), ('trade', 'friction', 'between'), ('friction', 'between', 'the'), ('between', 'the', 'U'), ('the', 'U', '.'), ('U', '.', 'S'), ('.', 'S', '.'), ('S', '.', 'And'), ('.', 'And', 'Japan'), ('And', 'Japan', 'has'), ('Japan', 'has', 'raised'), ('has', 'raised', 'fears'), ('raised', 'fears', 'among'), ('fears', 'among', 'many'), ('among', 'many', 'of'), ('many', 'of', 'Asia'), ('of', 'Asia', "'"), ('Asia', "'", 's'), ("'", 's', 'exporting'), ('s', 'exporting', 'nations'), ('exporting', 'nations', 'that'), ('nations', 'that', 'the'), ('that', 'the', 'row'), ('the', 'row', 'could'), ('row', 'could', 'inflict'), ('could', 'inflict', 'far'), ('inflict', 'far', '-'), ('far', '-', 'reaching'), ('-', 'reaching', 'economic'), ('reaching', 'economic', 'damage'), ('economic', 'damage', ','), ('damage', ',', 'businessmen'), (',', 'businessmen', 'and'), ('businessmen', 'and', 'officials'), ('and', 'officials', 'said'), ('officials', 'said', '.'), ('said', '.', None), ('.', None, None)]

# %%
# How many trigrams in n word sentence?

# %%
# Word count
print(len(first_sentence))
# Out:
# 49

# %%
# Trigram count
print(len(list(trigrams(first_sentence, pad_left=True, pad_right=True))))
# Out:
# 51

# %% [markdown]
# # Reuters trigram model

# %%
# Our model will be a dictionary that maps trigram -> number of occurrences in reuters data
# By default we have zero for all trigrams (this is why we use defaultdict and not dict)
model = defaultdict(lambda: defaultdict(lambda: 0))
 
# Iterated through all sentences in the dataset
for sentence in reuters.sents():
    # For each trigram in the sentence
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        # Increase occurence count
        model[(w1, w2)][w3] += 1

# %%
# How many times does "economists" follow "what the"?
print(model["", ""][""]) # "economists" follows "what the" 2 times
# Out:
# 2

# %%
# How many times does "noneexistingword" follow "what the"?
print(model["", ""][""]) # 0 times
# Out:
# 0

# %%
print(model[,][""]) # 8839 sentences start with "The"?
# Out:
# 8839

# %% [markdown]
# ## Intuition for probabilities in trigram model
#
# Consider the sentences
#
# - _Carlos needs a haircut_
# - _Carlos needs a new pair of shoes_
#
# The trigrams are
#
# - (Carlos, needs, a) (2)
# - (needs, a, haircut) (1)
# - (needs, a, new) (1)
# - (a, new, pair) (1)
# - (pair, of, shoes) (1)
#
# Our language model can now predict conditional probabilities for words given the context:
#
# Carlos, needs -> ???
#
# a: 1.0
# carlos: 0.0
# needs: 0.0
# new: 0.0
# haircut: 0.0
# shoes: 0.0
#
# needs, a ->
#
#
# a: 0.0
# carlos: 0.0
# needs: 0.0
# new: 0.5
# haircut: 0.5
# shoes: 0.0
#
# Mathematically this can be expressed as the conditional probability P (w[i] | w[i-1], w[i-2])

# %% [markdown]
# ## Reuters trigram text generation
#
# Let's get a word prediction given 2 words from our trigram model

# %%
# Compute probabilities from counts
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        # Divide the number of times a trigram appears by the total count of trigrams
        model[w1_w2][w3] /= total_count

# %%
# View language model output for "what the"
prediction = model["I", "Shall"]

prediction_sorted = sorted(prediction.items(), key=lambda kv: -kv[1])

for word, conditional_probability in prediction_sorted:
    print(word, conditional_probability)

# %%
import numpy as np
from itertools import compress

text = [None, None]
end_sentence = False

while not end_sentence:
    
    # Obtain predictions for next word based on the lastest 2 words
    predictions = model[tuple(text[-2:])]
 
    prediction_items = predictions.items()
    probs = [p[1] for p in prediction_items]
    words = [p[0] for p in prediction_items]
    
    # Randomly select next word considering conditional probabilities
    s = np.random.multinomial(1, probs) # [0 0 0 1 0 0 0]
    candidate = list(compress(words, s))[0]
    text.append(candidate)
    
    if candidate == None:
        end_sentence = True

print(text)
# Out:
# [None, None, 'HILTON', '&', 'lt', ';', 'XON', '>', 'EXTENDS', 'MID', '-', 'GRADE', 'UNLEADED', 'MARKETING', 'Exxon', 'Co', 'U', '.', 'S', '.', 'companies', 'from', 'trading', 'on', 'NASDAQ', ',', 'while', 'residual', 'fuel', 'went', 'into', 'stocks', '.', None]

# %% [markdown]
# # Lyrics

# %%
# Load poetry
file = open("DonOmar/Blue Zone.txt", "r") 

new_line_sentinel = " _NL_ "

# In poetry, new lines are very important. Workaround to capture the new line in the tokenizer
poetry = file.read().replace("\n", new_line_sentinel)

# %%
import os

# %%
all_files = os.listdir("DonOmar/")

# %%
#Load lyrics
all_songs = []
for name_file in all_files:
    file = open("DonOmar/" + name_file, 'r')
    all_songs.append(file.read().replace("\n", new_line_sentinel))

# %%
# How many songs?
# Out:
# 358

# %%
# Tokenization
poetry_tokenized = []
for song in all_songs:
    poetry_tokenized += nltk.word_tokenize(song)

# %%
print(poetry_tokenized[0:100])
# Out:
# ['Natty', 'natasha_NL_Ahora', 'entiendo', 'es', 'tan', 'difícil', 'de', 'aceptar_NL_Que', 'tuvimos', 'tanto', 'para', 'dar_NL_Y', 'con', 'el', 'tiempo', 'se', 'acabo', 'nuestro', 'camino_NL__NL_Natty', 'natasha_NL_Ahora', 'entiendo', 'es', 'tan', 'difícil', 'de', 'aceptar_NL_Que', 'tuvimos', 'tanto', 'para', 'dar_NL_Y', 'con', 'el', 'tiempo', 'se', 'acabo', 'nuestro', 'camino_NL_Ahora', 'entiendo', 'es', 'tan', 'difícil', 'de', 'aceptar_NL_Que', 'tuvimos', 'tanto', 'para', 'dar_NL_Y', 'con', 'el', 'tiempo', 'se', 'acabo', 'nuestro', 'caminoDon', 'omar_NL_Que', 'paraíso', 'construimos', 'si', 'al', 'final_NL_Termino', 'por', 'derribarnos', 'la', 'ansiedad_NL_No', 'supimos', 'rescatarnos', 'y', 'cambio', 'nuestro', 'destino_NL_Don', 'omar_NL_Que', 'paraíso', 'construimos', 'si', 'al', 'final_NL_Termino', 'por', 'derribarnos', 'la', 'ansiedad_NL_No', 'supimos', 'rescatarnos', 'y', 'cambio', 'nuestro', 'destinoNatty', 'natasha_NL_Me', 'duele', 'tanto', 'imaginar_NL_Todo', 'lo', 'que', 'no', 'vivimos', 'morirá_NL_No', 'me', 'atrevo', 'a', 'resignarme', 'a']

# %%
# Generate some poetry: build language model and generate!

# Our model will be a dictionary that maps trigram -> number of occurrences in reuters data
# By default we have zero for all trigrams (this is why we use defaultdict and not dict)
poetry_model = defaultdict(lambda: defaultdict(lambda: 0))
 

# For each trigram in the sentence
for w1, w2, w3 in trigrams(poetry_tokenized, pad_right=True, pad_left=True):
    # Increase occurence count
    poetry_model[(w1, w2)][w3] += 1

# %%
poetry_model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(None,
#               None): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Natty': 1}),
#              (None,
#               'Natty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'natasha_NL_Ahora': 1}),
#              ('Natty',
#               'natasha_NL_Ahora'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'entiendo': 1}),
#              ('natasha_NL_Ahora',
#               'entiendo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'es': 2}),
#              ('entiendo',
#               'es'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tan': 3}),
#              ('es',
#               'tan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'difícil': 3,
#                           'fácil': 2,
#                           'impactante_NL_tan': 3,
#                           'sato_NL_se': 7,
#                           'puro_NL_Que': 4}),
#              ('tan',
#               'difícil'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'de': 3}),
#              ('difícil',
#               'de'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aceptar_NL_Que': 3}),
#              ('de',
#               'aceptar_NL_Que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tuvimos': 3,
#                           'tubimos': 2}),
#              ('aceptar_NL_Que',
#               'tuvimos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tanto': 3}),
#              ('tuvimos',
#               'tanto'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'para': 3}),
#              ('tanto',
#               'para'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dar_NL_Y': 3,
#                           'dar_NL_': 3}),
#              ('para',
#               'dar_NL_Y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'con': 3}),
#              ('dar_NL_Y',
#               'con'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'el': 3}),
#              ('con',
#               'el'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tiempo': 9,
#                           'canto': 11,
#                           'rebuleo_NL_Y': 32,
#                           'viejo': 5,
#                           'peine': 4,
#                           'jefe': 2,
#                           'sufrimiento': 2,
#                           ',': 8,
#                           'Don_NL_No': 4,
#                           'ritmo': 12,
#                           'Boster': 2,
#                           'te': 2,
#                           ')': 8,
#                           'que': 6,
#                           'racho': 2,
#                           'bajo_NL_Que': 1,
#                           'bajo': 1,
#                           'bloque_NL_Este': 1,
#                           'bloquepakevaspatapata': 1,
#                           'corazon': 10,
#                           'corazon._NL_3': 2,
#                           'desafío_NL_Y': 2,
#                           'novio': 12,
#                           'cuerpo': 12,
#                           'movil': 2,
#                           'don_NL_Asustando': 2,
#                           'impacto': 2,
#                           'monster_NL_Ya': 1,
#                           'monsterElla': 1,
#                           'codo': 2,
#                           'disfraz': 2,
#                           'duro': 6,
#                           'canto_NL_en': 4,
#                           'mar': 4,
#                           "guayeteo'_NL_pa": 18,
#                           'fogoneo_NL_Esta': 3,
#                           'pelo': 9,
#                           'mono': 2,
#                           'ya': 2,
#                           'rufián_NL_Con': 2,
#                           'pelo_NL_Se': 9,
#                           'palo': 2,
#                           'bikini_NL_tiene': 2,
#                           'canto_NL_Don': 2,
#                           "guayeteo'_NL_Pa": 24,
#                           'hunter': 4,
#                           'nene': 3,
#                           'corazón': 2,
#                           'fronte_NL_Tienes': 2,
#                           'azuquita': 6,
#                           'em-di': 4,
#                           'fogoneo_NL_La': 1,
#                           'fogoneoEsta': 1,
#                           'tiburon': 2,
#                           'don_NL_': 2,
#                           'mapa': 2,
#                           'mio._NL_': 2,
#                           'sol': 2,
#                           'rey': 2,
#                           'jefe_NL_Pá': 2,
#                           'jefe_NL_Pa': 2,
#                           'Tonka_NL_Tu': 12,
#                           'Tonka_NL_Cierrale': 2,
#                           'mismo': 2,
#                           'Tonka_NL_Eliel': 2,
#                           'Tonka_NL_': 1,
#                           'TonkaRonca': 1,
#                           'kapuni_NL_Empezó': 10,
#                           'kapuni': 4,
#                           'crack_NL_Nos': 2,
#                           'es': 2,
#                           'Don_NL_Traiganse': 2,
#                           'cabo_NL_Tírenme': 2,
#                           'otro': 2,
#                           'father_NL_': 2,
#                           'full': 2,
#                           'témpano': 2,
#                           'tanque_NL_Si': 2,
#                           'automático_NL_Métele': 4,
#                           'Don': 4,
#                           'boster': 2,
#                           'Don_NL_traiganse': 2}),
#              ('el',
#               'tiempo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'se': 10,
#                           'corre': 2,
#                           'no': 5,
#                           'me': 2,
#                           'si': 4,
#                           'de': 2,
#                           'junto': 3,
#                           'pasa_NL_Te': 2,
#                           'lo': 10,
#                           'decida_NL_Si': 2,
#                           ',': 2,
#                           'pasa': 4,
#                           'q': 2,
#                           'todavía': 6,
#                           'y': 8,
#                           'todavia': 2,
#                           'te': 4}),
#              ('tiempo',
#               'se'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'acabo': 3,
#                           'hizo': 6,
#                           'esta': 4,
#                           'acabo_NL_Nuestro': 3}),
#              ('se',
#               'acabo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nuestro': 3,
#                           '.': 2,
#                           'el': 4,
#                           '(': 2}),
#              ('acabo',
#               'nuestro'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'camino_NL__NL_Natty': 1,
#                           'camino_NL_Ahora': 1,
#                           'caminoDon': 1}),
#              ('nuestro',
#               'camino_NL__NL_Natty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'natasha_NL_Ahora': 1}),
#              ('camino_NL__NL_Natty',
#               'natasha_NL_Ahora'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'entiendo': 1}),
#              ('nuestro',
#               'camino_NL_Ahora'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'entiendo': 1}),
#              ('camino_NL_Ahora',
#               'entiendo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'es': 1}),
#              ('nuestro',
#               'caminoDon'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'omar_NL_Que': 1}),
#              ('caminoDon',
#               'omar_NL_Que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'paraíso': 1}),
#              ('omar_NL_Que',
#               'paraíso'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'construimos': 2}),
#              ('paraíso',
#               'construimos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'si': 2}),
#              ('construimos',
#               'si'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'al': 2}),
#              ('si',
#               'al'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'final_NL_Termino': 2,
#                           'besarle': 2}),
#              ('al',
#               'final_NL_Termino'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'por': 4}),
#              ('final_NL_Termino',
#               'por'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'derribarnos': 4}),
#              ('por',
#               'derribarnos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'la': 4}),
#              ('derribarnos',
#               'la'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ansiedad_NL_No': 2,
#                           'anciedad_NL_No': 2}),
#              ('la',
#               'ansiedad_NL_No'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'supimos': 2}),
#              ('ansiedad_NL_No',
#               'supimos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rescatarnos': 2}),
#              ('supimos',
#               'rescatarnos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 2,
#                           '&': 2}),
#              ('rescatarnos',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cambio': 2}),
#              ('y',
#               'cambio'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nuestro': 2}),
#              ('cambio',
#               'nuestro'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'destino_NL_Don': 1,
#                           'destinoNatty': 1}),
#              ('nuestro',
#               'destino_NL_Don'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'omar_NL_Que': 1}),
#              ('destino_NL_Don',
#               'omar_NL_Que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'paraíso': 1}),
#              ('nuestro',
#               'destinoNatty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'natasha_NL_Me': 1}),
#              ('destinoNatty',
#               'natasha_NL_Me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'duele': 1}),
#              ('natasha_NL_Me',
#               'duele'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tanto': 2}),
#              ('duele',
#               'tanto'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'imaginar_NL_Todo': 4,
#                           'imaginar_NL_Un': 4}),
#              ('tanto',
#               'imaginar_NL_Todo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lo': 4}),
#              ('imaginar_NL_Todo',
#               'lo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 4}),
#              ('lo',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'no': 28,
#                           'yo': 24,
#                           'digan': 8,
#                           'llore': 4,
#                           'tu': 50,
#                           'quiera_NL_Entonces': 4,
#                           'quiera_NL_Agarrala': 8,
#                           'quieraDale': 1,
#                           'quiera': 28,
#                           'quieraEntonces': 1,
#                           'quieraAgarrala': 1,
#                           'quieraHector': 1,
#                           'he': 5,
#                           'me': 12,
#                           'piense': 5,
#                           'quiero': 69,
#                           'escuche_NL_Dejare': 4,
#                           'sucedio_NL_Todavia': 6,
#                           'siento_NL_': 6,
#                           'la': 6,
#                           'escuche': 2,
#                           'aspira_NL_Química': 2,
#                           'se': 12,
#                           'cualquiera': 2,
#                           'te': 36,
#                           'Luny': 2,
#                           'hago': 4,
#                           'el': 10,
#                           'enrolo': 2,
#                           'tengas_NL_Que': 2,
#                           'antes': 3,
#                           'Le': 3,
#                           'quise': 6,
#                           'mas': 2,
#                           'digan_NL_Chillin': 4,
#                           'tanto': 2,
#                           'das': 6,
#                           'mato': 4,
#                           'hago_NL_Que': 4,
#                           'estan': 4,
#                           'hicimos': 6,
#                           'paso': 4,
#                           'nunca': 2,
#                           'tiene': 13,
#                           'tengo': 7,
#                           'falta': 3,
#                           'ustedes': 4,
#                           'viene': 4,
#                           'hacer': 3,
#                           'cosecho_NL_Y': 1,
#                           'cosechoVáyanse': 1,
#                           'ti': 2,
#                           'quiero_NL_Conocer': 2,
#                           'damos': 5,
#                           'un': 3,
#                           'tengo_NL_Mas': 2,
#                           'hizo_NL_la': 3,
#                           'son': 2,
#                           'queria_NL_Pasar': 8,
#                           'es': 10,
#                           'voy': 4,
#                           'conspiran': 2,
#                           'piensa': 6,
#                           'a': 2,
#                           'siempre': 2,
#                           'quieres': 27,
#                           'fuera': 6,
#                           'desean_NL_Venimos': 2,
#                           'estoy': 4,
#                           'le': 8,
#                           'queria_NL_I': 2,
#                           'vale': 2,
#                           'después': 4,
#                           'podría': 2,
#                           'muestran': 2,
#                           'quería': 6,
#                           'pasa': 3,
#                           'faltaba': 3,
#                           'vamos': 14,
#                           'ella': 4,
#                           'quieroooo': 2,
#                           'hemos': 6,
#                           'piensas_NL_que': 2,
#                           'crees_NL_vente': 4,
#                           'piensas': 2,
#                           'fuims': 2,
#                           'anda': 6,
#                           'quieras': 2,
#                           '_NL_este': 2,
#                           'sea_NL_como': 2,
#                           'pasó_NL_Yo': 4,
#                           'cargo': 9,
#                           'cosecho': 2,
#                           'hizo._NL_Se': 2,
#                           'hace': 2,
#                           'pase': 4,
#                           'piensen_NL_Ríe': 2,
#                           'sea': 20,
#                           'los': 2,
#                           'crezco': 2,
#                           'enriquece': 2,
#                           'rompá_NL_Si': 2,
#                           'rompa_NL_Si': 2,
#                           'por': 4,
#                           'las': 12,
#                           'tú': 8,
#                           'quieres_NL_Por': 14,
#                           'ellos': 2,
#                           'queria': 4,
#                           'pide': 8,
#                           'hay': 2,
#                           'siento': 2,
#                           'siento_NL_Que': 2,
#                           'eliel': 2,
#                           'apesta': 2,
#                           'opinas_NL_Que': 4,
#                           'soy_NL_Yo': 3,
#                           'soyDamas': 1,
#                           'soyTodo': 1,
#                           'soy_NL_Todo': 2,
#                           'soyBueno': 1,
#                           'diga': 2,
#                           'su': 8,
#                           'sentimos_NL_Juntos': 2,
#                           'apesta_NL_Y': 3,
#                           'es_NL_tener': 3,
#                           'siente': 2,
#                           'jamás': 6,
#                           'soy_NL_Lejos': 3,
#                           'soyYo': 1,
#                           'soyNací': 1,
#                           'soyYandel': 1,
#                           'tengo_NL_Soy': 2,
#                           'haga': 2,
#                           'esta': 4}),
#              ('que',
#               'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'vivimos': 4,
#                           'es': 33,
#                           'hay': 8,
#                           'encuentre': 2,
#                           'jodan_NL_Los': 2,
#                           'jodanPegala': 2,
#                           'entiendo': 2,
#                           'estas': 22,
#                           'se': 46,
#                           'discrimina_NL_A': 1,
#                           'discriminaY': 1,
#                           'quiero': 8,
#                           'me': 44,
#                           'te': 23,
#                           'falla_NL_Hagan': 1,
#                           'fallaEl': 1,
#                           'puedo': 4,
#                           'hace': 6,
#                           'les': 5,
#                           'fantasmeo_NL_Que': 2,
#                           'haces': 2,
#                           'dimo': 2,
#                           'llamara': 2,
#                           'vacilen': 2,
#                           'veis': 2,
#                           'lo': 9,
#                           'habla': 2,
#                           'panda': 2,
#                           'volveria': 4,
#                           'soy': 17,
#                           'falla_NL_Sonoro': 2,
#                           'tenemos': 2,
#                           'tendrán': 2,
#                           'escucharan': 2,
#                           'la': 15,
#                           'tengo': 6,
#                           'iba': 4,
#                           'murio_NL_Amor': 2,
#                           'vas': 2,
#                           'van': 2,
#                           'han': 6,
#                           'meten': 6,
#                           'queria_NL_La': 2,
#                           'creyeron_NL_JAJAJAJAJA_NL_El': 3,
#                           'vengan': 3,
#                           'necesito': 20,
#                           '!': 12,
#                           'has': 6,
#                           'hacen': 2,
#                           'triki_NL_como': 2,
#                           'encontré_NL_que': 6,
#                           'sabe_NL_Don': 2,
#                           'encontré_NL_Que': 4,
#                           'ha': 4,
#                           'hemos': 4,
#                           'aguanto': 28,
#                           'sabe': 2,
#                           'pierda': 2,
#                           'nesesito': 5,
#                           'tiene': 4,
#                           'respeto_NL_como': 2,
#                           'trate': 2,
#                           'vale': 11,
#                           'pego': 2,
#                           'le': 4,
#                           'vaya': 2,
#                           'silve': 2,
#                           'digan': 2,
#                           'habrá': 3,
#                           ',': 80,
#                           'demore': 4,
#                           'inventes_NL_': 4,
#                           '...': 2,
#                           'estes': 29}),
#              ('no',
#               'vivimos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'morirá_NL_No': 2,
#                           'morira_NL_No': 2}),
#              ('vivimos',
#               'morirá_NL_No'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'me': 2}),
#              ('morirá_NL_No',
#               'me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'atrevo': 2}),
#              ('me',
#               'atrevo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 4}),
#              ('atrevo',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'resignarme': 4}),
#              ('a',
#               'resignarme'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 4}),
#              ('resignarme',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 4}),
#              ('a',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'termine': 2,
#                           'caiga': 2,
#                           'a': 2,
#                           'le': 2,
#                           'la': 4,
#                           'tu': 4,
#                           'se': 7,
#                           'me': 5,
#                           'mi': 2,
#                           'el': 2,
#                           'los': 2,
#                           'termine_NL_De': 2,
#                           'vaciles_NL_Y': 2,
#                           'hay': 2}),
#              ('que',
#               'termine'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'de': 2}),
#              ('termine',
#               'de'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'esta': 2}),
#              ('de',
#               'esta'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'forma': 2,
#                           'vamos': 4,
#                           'novela_NL_Para': 2,
#                           'soledad': 2,
#                           'pasion_NL_Por': 4,
#                           'música': 2,
#                           'joyeria_NL_Sencillo': 2,
#                           'nadie': 4,
#                           'historia_NL_viven': 2}),
#              ('esta',
#               'forma'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nuestro': 4}),
#              ('forma',
#               'nuestro'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'amor_NL_Natty': 1,
#                           'amorNatty': 1,
#                           'amor._NL_Me': 1,
#                           'amor.A': 1}),
#              ('nuestro',
#               'amor_NL_Natty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'natasha_NL_Me': 1}),
#              ('amor_NL_Natty',
#               'natasha_NL_Me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'duele': 1}),
#              ('nuestro',
#               'amorNatty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1}),
#              ('amorNatty',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'don_NL_A': 1}),
#              ('y',
#               'don_NL_A'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'donde': 4}),
#              ('don_NL_A',
#               'donde'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ira': 4}),
#              ('donde',
#               'ira'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tu': 8,
#                           ',': 2}),
#              ('ira',
#               'tu'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'corazón_NL_Por': 4,
#                           'corazon_NL_Por': 4}),
#              ('tu',
#               'corazón_NL_Por'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 4}),
#              ('corazón_NL_Por',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'camino': 4}),
#              ('que',
#               'camino'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'volara': 8}),
#              ('camino',
#               'volara'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tu': 8}),
#              ('volara',
#               'tu'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'voz_NL_Por': 8}),
#              ('tu',
#               'voz_NL_Por'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 8}),
#              ('voz_NL_Por',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'otros': 8}),
#              ('que',
#               'otros'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'labios': 12,
#                           '(': 3}),
#              ('otros',
#               'labios'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'viajara_NL_Tus': 6,
#                           'viajara_NL_Los': 6}),
#              ('labios',
#               'viajara_NL_Tus'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'besos': 6}),
#              ('viajara_NL_Tus',
#               'besos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 6}),
#              ('besos',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ayer': 12,
#                           'la': 2,
#                           'me': 4}),
#              ('que',
#               'ayer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'te': 12}),
#              ('ayer',
#               'te'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'entregué_NL_Me': 6,
#                           'entrege_NL_Me': 6}),
#              ('te',
#               'entregué_NL_Me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'perteneces': 6}),
#              ('entregué_NL_Me',
#               'perteneces'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pero': 6}),
#              ('perteneces',
#               'pero'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'no': 12}),
#              ('pero',
#               'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'eres': 12,
#                           'es': 3,
#                           'te': 2,
#                           'dejan': 2,
#                           'choteen_NL_Andas': 2,
#                           'quiero_NL_te': 3,
#                           'puedo_NL_soy': 3,
#                           'halla': 2,
#                           'lo': 4,
#                           'como': 2}),
#              ('no',
#               'eres'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'para': 12,
#                           'un': 2,
#                           'el': 6,
#                           'duro': 4}),
#              ('eres',
#               'para'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mí_NL_Natty': 1,
#                           'míNatty': 1,
#                           'mí.._NL_Natty': 1,
#                           'mí..Por': 1,
#                           'mí._NL_Por': 1,
#                           'mí': 1,
#                           'mi': 3,
#                           'mi._NL_A': 2,
#                           'mi.Intentaria': 1,
#                           'mi.Por': 1,
#                           'mi._NL_Por': 1}),
#              ('para',
#               'mí_NL_Natty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1}),
#              ('mí_NL_Natty',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'don_NL_A': 1}),
#              ('para',
#               'míNatty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'natasha_NL_Intentaría': 1}),
#              ('míNatty',
#               'natasha_NL_Intentaría'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'olvidar': 1}),
#              ('natasha_NL_Intentaría',
#               'olvidar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'de': 2}),
#              ('olvidar',
#               'de'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'continuar_NL_Talvez': 2}),
#              ('de',
#               'continuar_NL_Talvez'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'alguien': 2}),
#              ('continuar_NL_Talvez',
#               'alguien'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mas': 4}),
#              ('alguien',
#               'mas'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'en': 4}),
#              ('mas',
#               'en'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tu': 4,
#                           'una': 2}),
#              ('en',
#               'tu'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lugar_NL_Tu': 4,
#                           'mano': 32,
#                           'viaje': 6,
#                           'zona': 4,
#                           'puerta': 2,
#                           'padre': 6,
#                           'fiesta': 2,
#                           'antifaz': 2,
#                           'ropa': 2,
#                           'amor_NL_Y': 2,
#                           'cara_NL_Y': 4,
#                           'posición_NL_Quizás': 8,
#                           'cama': 6,
#                           'mente': 2,
#                           'vida': 14,
#                           'alcancia_NL_Quiero': 2,
#                           'casa': 2,
#                           'cielo_NL_medidos': 3,
#                           'posición': 2,
#                           'posicion._NL_Don': 2,
#                           'posicion.Aventura': 2,
#                           'posicion': 2,
#                           'caserio_NL_Te': 2,
#                           'cabeza': 2,
#                           'cara': 2,
#                           'mismo': 4,
#                           'pecho': 6}),
#              ('tu',
#               'lugar_NL_Tu'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sitio': 4}),
#              ('lugar_NL_Tu',
#               'sitio'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'no': 4}),
#              ('sitio',
#               'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'le': 4}),
#              ('no',
#               'le'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pertenece': 4,
#                           'puedo': 2,
#                           'doy': 2,
#                           'temo': 2,
#                           'digas': 2,
#                           'hago': 2,
#                           'mientas': 4,
#                           'meto': 2,
#                           'creo': 2,
#                           'creeria': 2,
#                           'meta': 2,
#                           'da': 2,
#                           'de': 13,
#                           'voy': 5,
#                           'des': 4,
#                           'importa': 2,
#                           'cojan': 2,
#                           'mienta': 4,
#                           'diste': 4,
#                           'salio': 2,
#                           'metas': 8}),
#              ('le',
#               'pertenece'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'desde': 4,
#                           'a': 2}),
#              ('pertenece',
#               'desde'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ahora_NL_Lo': 2,
#                           'ahora_NL_No': 2}),
#              ('desde',
#               'ahora_NL_Lo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lamento_NL_Natty': 1,
#                           'lamentoMe': 1}),
#              ('ahora_NL_Lo',
#               'lamento_NL_Natty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'natasha_NL_Intentaría': 1}),
#              ('lamento_NL_Natty',
#               'natasha_NL_Intentaría'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'olvidar': 1}),
#              ('ahora_NL_Lo',
#               'lamentoMe'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'duele': 1}),
#              ('lamentoMe',
#               'duele'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tanto': 1}),
#              ('tanto',
#               'imaginar_NL_Un'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sueno': 2,
#                           'sueño': 2}),
#              ('imaginar_NL_Un',
#               'sueno'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'incompleto': 2}),
#              ('sueno',
#               'incompleto'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'compartido_NL_Simplemente': 2}),
#              ('incompleto',
#               'compartido_NL_Simplemente'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'por': 2}),
#              ('compartido_NL_Simplemente',
#               'por'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 2}),
#              ('por',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 2,
#                           'no': 10,
#                           'yo': 2,
#                           'le': 2,
#                           'con': 2,
#                           'tienes': 3,
#                           'en': 2,
#                           'soy': 4,
#                           'es': 20,
#                           'ya': 2,
#                           'voy': 2,
#                           'tu': 2}),
#              ('que',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'quien': 2,
#                           'mi': 15,
#                           'una': 2,
#                           'mi_NL_Que': 2,
#                           'ustedes': 4,
#                           'la': 4,
#                           'cualquiera': 2,
#                           'ella': 2,
#                           'mí': 2,
#                           'jehová': 2,
#                           'corrio': 4,
#                           'ti': 2,
#                           'vacila': 2,
#                           'puesto': 4,
#                           'pecar': 16,
#                           'vacilao': 2,
#                           'Jehová': 2,
#                           'lluvia._NL_Prraaa': 2,
#                           'tu': 2,
#                           'gente': 2,
#                           'pesar': 2,
#                           'to': 2}),
#              ('a',
#               'quien'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'le': 6,
#                           'no': 2,
#                           'ha': 6}),
#              ('quien',
#               'le'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pertenezco': 2,
#                           'guste': 2,
#                           'duela': 2,
#                           'quita': 2}),
#              ('le',
#               'pertenezco'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'no': 2}),
#              ('pertenezco',
#               'no'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'estará': 2}),
#              ('no',
#               'estará'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ya': 2}),
#              ('estará',
#               'ya'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'junto': 2}),
#              ('ya',
#               'junto'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 2,
#                           'ami._NL_Me': 1,
#                           'ami.A': 1}),
#              ('junto',
#               'a'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mi_NL_Me': 1,
#                           'miNatty': 1,
#                           '(': 2,
#                           'ti_NL_Lo': 3,
#                           'mí_NL_Oh': 2,
#                           'mí': 4,
#                           'mí_NL_Si': 12}),
#              ('a',
#               'mi_NL_Me'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'duele': 1}),
#              ('mi_NL_Me',
#               'duele'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tanto': 1}),
#              ('a',
#               'miNatty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1}),
#              ('miNatty',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'don_NL_A': 1}),
#              ('para',
#               'mí.._NL_Natty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 1}),
#              ('mí.._NL_Natty',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'don_NL_A': 1}),
#              ('para',
#               'mí..Por'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 1}),
#              ('mí..Por',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'otros': 1}),
#              ('para',
#               'mí._NL_Por'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'que': 1}),
#              ('mí._NL_Por',
#               'que'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'otros': 1}),
#              ('para',
#               'mí'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'.': 1,
#                           ',': 2}),
#              ('mí',
#               '.'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 1}),
#              ('.',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Vieja': 1,
#                           'coro': 1,
#                           'Dale': 4,
#                           'odian': 2,
#                           'quieren': 2,
#                           'Bis': 5,
#                           '2': 2,
#                           'x2': 1,
#                           'a': 1,
#                           'Gilberto': 1,
#                           'Esta': 1,
#                           'entiendeme': 1,
#                           'Don': 3,
#                           'siente': 4,
#                           'dile': 2,
#                           'Coro': 2,
#                           '1': 1,
#                           'DON': 1,
#                           'don': 2,
#                           'cazame': 2,
#                           'acorralame': 2,
#                           'x3': 2,
#                           'Wooooh': 3,
#                           'Sencillo': 2,
#                           'DO': 1}),
#              ('(',
#               'Vieja'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'te': 2,
#                           ',': 2}),
#              ('Vieja',
#               'te'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'amo': 2}),
#              ('te',
#               'amo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'oiste': 2,
#                           ')': 2,
#                           ',': 8,
#                           'demaciado': 2,
#                           '(': 2,
#                           '...': 2,
#                           'vieja': 2,
#                           '[': 1}),
#              ('amo',
#               'oiste'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {')': 2}),
#              ('oiste',
#               ')'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_': 2}),
#              (')',
#               '_NL_'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 739,
#                           "''": 9,
#                           '[': 26,
#                           'jajajjjaajajjajajaj_NL_': 2,
#                           "'": 2,
#                           '...': 4,
#                           '_NL__NL_Vamo': 1,
#                           '_NL_Unreleased_NL_Don': 1,
#                           'Probando_NL_Looney': 1}),
#              ('_NL_',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Para': 3,
#                           'esta': 1,
#                           'Aunque': 2,
#                           'Que': 37,
#                           'Homenaje': 1,
#                           'Vieja': 2,
#                           'Donde': 2,
#                           'Oye': 4,
#                           'Tu': 19,
#                           'Sigan': 1,
#                           'aceleera': 6,
#                           'don': 10,
#                           'omar': 6,
#                           'Sera': 12,
#                           'Los': 6,
#                           'Don': 75,
#                           'Ya': 7,
#                           'Homerun': 4,
#                           'Luny': 10,
#                           'Con': 3,
#                           'Hoy': 4,
#                           'Ella': 4,
#                           '``': 14,
#                           'Yo': 21,
#                           'Papi': 6,
#                           'Hey': 3,
#                           'coro': 2,
#                           'EL': 2,
#                           'LOS': 2,
#                           'DY': 1,
#                           'Abusador': 2,
#                           'QUITATE': 2,
#                           'TA': 2,
#                           'LET': 2,
#                           'Looney': 11,
#                           'Dale': 35,
#                           'A': 6,
#                           'Boster': 2,
#                           'Una': 4,
#                           'Se': 17,
#                           'Sorprendente': 3,
#                           'Nes-ty': 2,
#                           'Eliel': 26,
#                           'D-o-n': 6,
#                           'Nesty': 6,
#                           'Ahhh': 37,
#                           'Grayskull': 18,
#                           'Otro': 1,
#                           'Sencillo': 2,
#                           'El': 42,
#                           'cuida': 6,
#                           'usted': 4,
#                           'repetir': 1,
#                           'La': 1,
#                           'Are': 2,
#                           'Si': 2,
#                           "I'Don": 5,
#                           'Sienta': 2,
#                           'ye': 3,
#                           'hey': 1,
#                           'HEY': 2,
#                           'Como': 5,
#                           'Evo': 3,
#                           'Esto': 5,
#                           'yo': 13,
#                           'Eso': 1,
#                           'Bienvenidos': 2,
#                           'Lo': 3,
#                           'Todo': 5,
#                           'Mamita': 2,
#                           'Remix': 3,
#                           'Sin': 20,
#                           'Sigue': 2,
#                           'Vamo': 6,
#                           'daddy': 3,
#                           'Blass': 4,
#                           'Hector': 2,
#                           'Gargolas': 2,
#                           'Mi': 16,
#                           'En': 8,
#                           'el': 13,
#                           'Tú': 2,
#                           'cintura': 3,
#                           'quien': 12,
#                           'Nosotros': 2,
#                           'Coro': 8,
#                           'X2': 2,
#                           'Envuelto_NL_desde': 8,
#                           'estribillo': 3,
#                           'oye': 2,
#                           'pas-pas-pasto': 3,
#                           'tu': 7,
#                           'matadores': 3,
#                           'looney': 5,
#                           'pasto': 6,
#                           'perrea': 30,
#                           'tienes': 3,
#                           'Ñengo': 3,
#                           'Walde': 3,
#                           'Deevani': 1,
#                           'Tito': 1,
#                           'Beenie': 1,
#                           'm-v-p': 3,
#                           'Ooo': 1,
#                           'Nena': 2,
#                           'D': 3,
#                           'x2': 13,
#                           'Ay': 17,
#                           'Toma': 2,
#                           'Bailando': 2,
#                           'Aprieta': 2,
#                           'los': 2,
#                           'dy': 1,
#                           'abusador': 2,
#                           'quitate': 2,
#                           'ta': 2,
#                           'let': 2,
#                           'ahora': 3,
#                           'ladys': 2,
#                           'no': 4,
#                           'nati': 2,
#                           'gyptian': 2,
#                           'Y': 12,
#                           'Mary': 3,
#                           'Deja': 7,
#                           'Pla': 3,
#                           'De-De-Deja': 7,
#                           'Es': 4,
#                           'Juana': 6,
#                           'Su': 5,
#                           'De-Deja': 2,
#                           'Hit': 18,
#                           'mix': 2,
#                           'v.i': 2,
#                           'carolina': 2,
#                           'olviden': 2,
#                           'la': 2,
#                           'Bien': 18,
#                           'Me': 4,
#                           'olle': 4,
#                           'WISIN': 1,
#                           'Glory': 16,
#                           'eliel': 3,
#                           'a': 1,
#                           'Miralo': 2,
#                           'Pas-pas-pas-pasto': 3,
#                           'Matadores': 6,
#                           'Pasto': 8,
#                           'Perrea': 40,
#                           'Tienes': 4,
#                           'Ok': 1,
#                           'DON': 2,
#                           'ZION': 1,
#                           'ALEXIS': 1,
#                           'FIDO': 1,
#                           'Viejo': 1,
#                           'siente': 4,
#                           'rarf': 18,
#                           'Oooooeeee': 2,
#                           '¡Vuelve': 2,
#                           'Hable': 5,
#                           'Les': 5,
#                           'Bling': 5,
#                           'Ustedes': 1,
#                           'Jajajaja': 2,
#                           '1': 1,
#                           'KENDO': 2,
#                           'kendo': 3,
#                           'Dúo': 3,
#                           "'": 3,
#                           'Atiende': 1,
#                           'Yandeeeeeeeeeeeel': 2,
#                           'Pas-pas-pasto': 3,
#                           'latinos': 16,
#                           'Bailalo': 2,
#                           'es': 2,
#                           'imaginate': 2,
#                           '...': 2,
#                           'sabes': 2,
#                           'dificil': 2,
#                           'para': 2,
#                           'entre': 2,
#                           'rell': 3,
#                           'shhh': 2,
#                           'Ohhh': 18,
#                           'del': 2,
#                           'crack': 2,
#                           'ohhh': 18,
#                           'glow': 2,
#                           'seduceme': 2,
#                           'Ronca': 9,
#                           'Grrrrrr': 3,
#                           'Wooooh': 21,
#                           'Uh': 95,
#                           'Aguanta': 3,
#                           'Jamas': 2,
#                           'Tenga': 2,
#                           'She': 1,
#                           'Robin': 3,
#                           'Soy': 6,
#                           'Duro': 4,
#                           'Coro2': 2,
#                           'Héctor': 2,
#                           'Ese': 1,
#                           '¡Pasión': 3,
#                           'No': 3,
#                           'AHHHH': 74,
#                           'Baby': 2,
#                           'Oh': 3,
#                           '¿Quien': 2,
#                           'Te': 4,
#                           'Ma': 4,
#                           'luny': 1,
#                           'Prrrrrrrrrra': 2,
#                           'Mas': 5,
#                           '¿Pa': 4,
#                           'Seguimos': 2,
#                           'Bambino': 2,
#                           'Coming': 6,
#                           'Cuanto': 9,
#                           'Loney': 2,
#                           'DO': 2,
#                           'y': 2,
#                           'Echo': 4,
#                           'Así': 2,
#                           'Buddha': 1}),
#              ('(',
# ...
#                           'encanta': 6}),
#              ('_NL_Te',
#               'voy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'a': 12,
#                           'sacar': 6}),
#              ('la',
#               'ligaLos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'vegaton': 1}),
#              ('ligaLos',
#               'vegaton'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'quedandose': 1}),
#              ('vegaton',
#               'quedandose'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'con': 2}),
#              ('quedandose',
#               'con'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'el': 2}),
#              ('(',
#               'aceleera'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'y': 18}),
#              ('aceleera',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'meteme': 18}),
#              ('meteme',
#               ')'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_Angel': 2,
#                           '_NL_Ya': 2,
#                           '_NL_Sin': 2,
#                           '_NL_Los': 3,
#                           '_NL_Yo': 2,
#                           'All': 1,
#                           '_NL_': 4,
#                           '_NL_All': 1,
#                           'Don': 1}),
#              ('_NL_Angel',
#               'Doze'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 2}),
#              ('Doze',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aceleera': 2}),
#              (')',
#               '_NL_Ya'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tu': 2,
#                           'voy': 4,
#                           'no': 9,
#                           'que': 7,
#                           'ya_NL_Farru_NL_Squiribi': 1,
#                           'yo': 12}),
#              ('_NL_Ya',
#               'tu'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sabes': 4}),
#              ('sabes',
#               'jerry'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 2}),
#              ('jerry',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aceleera': 2}),
#              (')',
#               '_NL_Sin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'hacer': 2,
#                           'pensarlo': 2,
#                           'miedo': 1}),
#              ('_NL_Sin',
#               'hacer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mucho': 2}),
#              ('hacer',
#               'mucho'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ruido': 2}),
#              ('mucho',
#               'ruido'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 2,
#                           'ella': 8}),
#              ('ruido',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aceleera': 2}),
#              (')',
#               '_NL_Los'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bandoleros': 4,
#                           'vegaton': 1,
#                           'Homerunners': 4,
#                           'que': 1,
#                           'mate': 2,
#                           'lo': 2,
#                           'alamos': 2,
#                           'coles': 2,
#                           'lamos': 2,
#                           'latinos': 2,
#                           'Presidentes_NL_Rebol': 1,
#                           'PresidentesHey': 1}),
#              ('_NL_Los',
#               'bandoleros'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'quedandonos': 2,
#                           'te': 3}),
#              ('bandoleros',
#               'quedandonos'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'con': 2}),
#              ('quedandonos',
#               'con'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'el': 2}),
#              (')',
#               '_NL_Yo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'si': 2,
#                           'a': 2,
#                           'estoy': 18,
#                           'soy': 9,
#                           'no': 3,
#                           'vivo': 16,
#                           'daría': 2,
#                           'la': 3,
#                           'Quiero': 4,
#                           'fui': 4,
#                           'nunca': 2,
#                           'Bajo': 4,
#                           'recorriendo': 2,
#                           'vengo': 2,
#                           'me': 1,
#                           'voy': 3,
#                           'Se': 2,
#                           'tocar': 4}),
#              ('_NL_Yo',
#               'si'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'soy': 2}),
#              ('si',
#               'soy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'la': 2,
#                           'vago': 2,
#                           'todo': 2,
#                           'el': 2,
#                           'solito_NL_entonces': 2,
#                           'un': 2,
#                           'de': 2}),
#              ('soy',
#               'la'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'diferencia': 2,
#                           'Cara': 2,
#                           'cura': 18,
#                           'esperanza': 2,
#                           'voz': 2}),
#              ('la',
#               'diferencia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'jajaja': 2,
#                           '...': 2}),
#              ('diferencia',
#               'jajaja'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 2}),
#              ('jajaja',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aceleera': 2}),
#              ('_NL_Los',
#               'vegaton'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'quedandose': 1}),
#              (')',
#               'All'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'star': 1}),
#              ('All',
#               'star'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Records_NL_Blin': 1}),
#              ('star',
#               'Records_NL_Blin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Blin': 2}),
#              ('Records_NL_Blin',
#               'Blin'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'music_NL_Juaaa': 2}),
#              ('Blin',
#               'music_NL_Juaaa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Juaaaa': 2}),
#              ('music_NL_Juaaa',
#               'Juaaaa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 2}),
#              ('Juaaaa',
#               '('): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'meteme': 8}),
#              ('el',
#               'chanbom'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pataaa': 8}),
#              ('chanbom',
#               'pataaa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'abajo': 8}),
#              (')',
#               '_NL_Juaaa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Juaaaa': 6}),
#              ('_NL_Juaaa',
#               'Juaaaa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 6}),
#              ('meteme',
#               'y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'meteme': 6}),
#              (')',
#               '_NL_All'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'star': 3}),
#              ('_NL_All',
#               'star'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'Records_NL_Blin': 1,
#                           '(': 2}),
#              (')',
#               'Don'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'omar': 1,
#                           '!': 5,
#                           ':': 5}),
#              ('Don',
#               'omar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'!': 1,
#                           ':': 1,
#                           '&': 2,
#                           ')': 5,
#                           'el': 3}),
#              ('omar',
#               '!'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_entonces': 5,
#                           '_NL_y': 3,
#                           '_NL_pegala_NL_acorralala_NL_pegala_NL_acorralala_NL_pegala_NL_acorralala_NL_pegala_NL_Entonces': 3,
#                           ')': 3,
#                           '!': 2}),
#              ('!',
#               '_NL_entonces'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'acorralala': 5}),
#              ('_NL_entonces',
#               'acorralala'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 15}),
#              ('acorralala',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_pegala': 12,
#                           '_NL_don': 9,
#                           '_NL_entonces': 6}),
#              ('...',
#               '_NL_pegala'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 33,
#                           'de': 3}),
#              ('_NL_pegala',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_acorralala': 12,
#                           '_NL_don': 3,
#                           '_NL_pegala': 6,
#                           '_NL_omar': 3,
#                           '_NL_looney': 3,
#                           '_NL_y': 6}),
#              ('...',
#               '_NL_acorralala'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 12}),
#              ('_NL_acorralala',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_pegala': 15}),
#              ('...',
#               '_NL_don'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'omar': 9,
#                           '...': 3}),
#              ('_NL_don',
#               'omar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'!': 6,
#                           '...': 3,
#                           ',': 3}),
#              ('...',
#               '_NL_omar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 3}),
#              ('_NL_omar',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_': 3}),
#              ('...',
#               '_NL_'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'(': 272,
#                           '[': 16,
#                           "''": 4,
#                           '...': 4}),
#              ('(',
#               'don'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 3,
#                           'omar': 74,
#                           '!': 20,
#                           ')': 13}),
#              ('don',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {')': 3,
#                           '_NL_': 2}),
#              ('(',
#               'omar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 3,
#                           '!': 3,
#                           ')': 8}),
#              ('omar',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {')': 3,
#                           '_NL_entonces': 3,
#                           '_NL_Ha': 2,
#                           '_NL__NL_El': 1,
#                           '_NL_Don': 1,
#                           'Bailen': 1}),
#              (')',
#               '_NL_acorralala'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 3}),
#              ('...',
#               '_NL_looney'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tunes': 3}),
#              ('_NL_looney',
#               'tunes'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 3}),
#              ('tunes',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_y': 3,
#                           ')': 2,
#                           '_NL_tu': 2}),
#              ('...',
#               '_NL_y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'noriega': 3,
#                           'acorralala': 3,
#                           'entonces': 3,
#                           'sin': 1}),
#              ('_NL_y',
#               'noriega'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'...': 3,
#                           '!': 3}),
#              ('noriega',
#               '...'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_reynaldo': 3}),
#              ('...',
#               '_NL_reynaldo'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'!': 3}),
#              ('_NL_reynaldo',
#               '!'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_Entonces': 3}),
#              ('!',
#               '_NL_Entonces'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'acorralala_NL_pegala': 3,
#                           'vuelve': 2}),
#              ('_NL_Entonces',
#               'acorralala_NL_pegala'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'de': 6}),
#              ('acorralala_NL_pegala',
#               'de'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'una': 9}),
#              ('de',
#               'una'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'esquina': 25,
#                           'via_NL_pero': 4,
#                           'vez': 12,
#                           'forma': 7,
#                           'noche': 2,
#                           'solitaria_NL_que': 3,
#                           'losa_NL_La': 2,
#                           'elipsis_NL_Que': 8,
#                           'profesión': 2,
#                           'mujer': 4,
#                           'niña': 5,
#                           'Niña': 3,
#                           'iglesia_NL_Y': 2,
#                           'fucking': 2,
#                           'emboscada': 2,
#                           'luna': 4,
#                           'loba_NL_Como': 2,
#                           'rubia': 2,
#                           'enfermedad': 4,
#                           'organizacion': 4,
#                           'lectura': 4,
#                           'vez_NL_Yo': 4,
#                           'losa_NL_______': 4,
#                           'elipsis': 4,
#                           'sustancia': 3}),
#              ('una',
#               'esquina'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {',': 18,
#                           '...': 3,
#                           '_NL_Como': 2,
#                           'la': 2,
#                           'pay': 4}),
#              ('esquina',
#               ','): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pai_NL_y': 18}),
#              (',',
#               'pai_NL_y'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sobala_NL_si': 18}),
#              ('pai_NL_y',
#               'sobala_NL_si'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'te': 18}),
#              ('sobala_NL_si',
#               'te'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pichea': 18}),
#              ('te',
#               'pichea'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'entonces': 22}),
#              ('pichea',
#               'entonces'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'_NL_socio': 18,
#                           'socio': 4}),
#              ('entonces',
#               '_NL_socio'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {',': 18}),
#              ('_NL_socio',
#               ','): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dejala_NL_que': 18}),
#              ...})

# %%
# Compute probabilities from counts
for w1_w2 in poetry_model:
    total_count = float(sum(poetry_model[w1_w2].values()))
    for w3 in poetry_model[w1_w2]:
        # Divide the number of times a trigram appears by the total count of trigrams
        poetry_model[w1_w2][w3] /= total_count

# %%
poetry_model["el", "tiempo"]
# Out:
# defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#             {'se': 0.14285714285714285,
#              'corre': 0.02857142857142857,
#              'no': 0.07142857142857142,
#              'me': 0.02857142857142857,
#              'si': 0.05714285714285714,
#              'de': 0.02857142857142857,
#              'junto': 0.04285714285714286,
#              'pasa_NL_Te': 0.02857142857142857,
#              'lo': 0.14285714285714285,
#              'decida_NL_Si': 0.02857142857142857,
#              ',': 0.02857142857142857,
#              'pasa': 0.05714285714285714,
#              'q': 0.02857142857142857,
#              'todavía': 0.08571428571428572,
#              'y': 0.11428571428571428,
#              'todavia': 0.02857142857142857,
#              'te': 0.05714285714285714})

# %%
# Compute probabilities from counts
for w1_w2 in poetry_model:
    total_count = float(sum(poetry_model[w1_w2].values()))
    for w3 in poetry_model[w1_w2]:
        # Divide the number of times a trigram appears by the total count of trigrams
        poetry_model[w1_w2][w3] /= total_count

# %%
new_line_sentinel = "_NL_"
poetry = ["tu", "sabe"]

for i in range(1, 50):

    # Obtain predictions for next word based on the lastest 2 words
    predictions = poetry_model[tuple(poetry[-2:])]

    prediction_items = predictions.items()
    probs = [p[1] for p in prediction_items]
    words = [p[0] for p in prediction_items]
    
    # Randomly select next word considering conditional probabilities
    s = np.random.multinomial(1, probs)
    candidate = list(compress(words, s))[0]
    poetry.append(candidate)


print(" ".join(poetry).replace(new_line_sentinel, "\n"))
# Out:
# tu sabe tu sabe
# la invacion
# ok mano arriba
# es el presidente
# el rey don
# let me see ya.inside
# echo diesel esta es la invasion
# nosotros somos genios . )
#  ( Coro ) Asi de sencillo ando con 50 titeres y a voz tan siquiera verte , por eso es lo mismo , no
# yo soy tu hombre
# tu
